# %%
library(dplyr)
library(tidyr)

# %%
All_RBP_motifs <- read.csv("/home/ylee/AllmotifDB/All_RBP_motifs.csv")
rbp_list <- unique(All_RBP_motifs$RBP_name)

# %% [markdown]
# ## Function

# %%
## alignment_details functions

alignment_details <- function(rbp_list, RBP_motifs, fimo_base_path) {
    motif_details <- data.frame(
        database = character(),
        RBP_name = character(),
        motif_id = character(),
        motif_alt_id = character(),
        alignment = logical(),
        start = numeric(),
        stop = numeric(),
        strand = character(),
        score = numeric(),
        p_value = numeric(),
        q_value = numeric(),
        matched_sequence = character(),
        stringsAsFactors = FALSE
    )
    
    for (rbp in rbp_list){
        fimo_file <- paste0(fimo_base_path, rbp, "/fimo.tsv")
        fimo_data <- read.delim(fimo_file, header = TRUE)

        motif_data <- RBP_motifs %>%
            filter(RBP_name == rbp) %>%
            select(database, RBP_name, motif_id, motif_alt_id)

        final_data <- list()
        for (i in 1:nrow(motif_data)) {
            if ("motif_id" %in% colnames(fimo_data) && "motif_alt_id" %in% colnames(fimo_data)){
                fimo_row <- fimo_data %>%  
                    filter(motif_id == motif_data[i, "motif_id"], motif_alt_id == motif_data[i, "motif_alt_id"])
                
                if (nrow(fimo_row) > 0) {
                    # If alignment data exists, fill in alignment data
                    alignment <- TRUE
                    start <- fimo_row$start
                    stop <- fimo_row$stop
                    strand <- fimo_row$strand
                    score <- fimo_row$score
                    p_value <- fimo_row$p.value
                    q_value <- fimo_row$q.value
                    matched_sequence <- fimo_row$matched_sequence
                } else {
                    # If no alignment data, set to NA
                    alignment <- FALSE
                    start <- NA
                    stop <- NA
                    strand <- NA
                    score <- NA
                    p_value <- NA
                    q_value <- NA
                    matched_sequence <- NA
                }
            }else {
                    # If no alignment data, set to NA
                    alignment <- FALSE
                    start <- NA
                    stop <- NA
                    strand <- NA
                    score <- NA
                    p_value <- NA
                    q_value <- NA
                    matched_sequence <- NA
            }

            
            # Create a data frame for the current motif and append to motif_details
            motif_details <- bind_rows(motif_details, data.frame(
                database = motif_data[i, "database"],
                RBP_name = motif_data[i, "RBP_name"],
                motif_id = motif_data[i, "motif_id"],
                motif_alt_id = motif_data[i, "motif_alt_id"],
                alignment = alignment,
                start = start,
                stop = stop,
                strand = strand,
                score = score,
                p_value = p_value,
                q_value = q_value,
                matched_sequence = matched_sequence,
                stringsAsFactors = FALSE
            ))
        }
    }
    return(motif_details)    
}

# %%
alignment_combined_details <- function(csv_paths, mapped_data, sequence_name) {
    alignment_combined <- data.frame(
        fragment_id = character(),
        database = character(),
        RBP_name = character(),
        motif_id = character(),
        motif_alt_id = character(),
        alignment = logical(),
        start = numeric(),
        stop = numeric(),
        strand = character(),
        score = numeric(),
        p_value = numeric(),
        q_value = numeric(),
        matched_sequence = character(),
        stringsAsFactors = FALSE
    )
    
    mapped_data[, 1] <- paste0(sequence_name, "_", mapped_data[, 1] + 1)
    colnames(mapped_data)[1] <- "fragment_id"
    mapped_data$motif_alignments <- NA
    
    for (csv_path in csv_paths){
        fragment_number <- as.numeric(sub(paste0(".*", sequence_name, "_(\\d+)\\.csv$"), "\\1", csv_path))
        fragment_start <- mapped_data[fragment_number, "position.in.adapting.gene.DNA"]
        
        alignment_df <- read.csv(csv_path)
        filtered_df <- alignment_df[alignment_df$alignment == TRUE, ]
        mapped_data$motif_alignments[fragment_number] <- nrow(filtered_df)
        
        if (nrow(filtered_df) > 0) {
            filtered_df$fragment_id <- paste0(sequence_name, "_", fragment_number)
            filtered_df$start <- filtered_df$start + fragment_start
            filtered_df$stop <- filtered_df$stop + fragment_start
            alignment_combined <- bind_rows(alignment_combined, filtered_df)
        }
    }

    return(list(alignment_combined = alignment_combined, mapped_data = mapped_data))
}

# %% [markdown]
# ## Combine Motif Scanning Result - Actg1

# %%
sequence_name = "Actg1_hotspot"                            ### Change Here : Actg1_hotspot, Actg1_ctrl, Actg1_random
base_dir <- paste0("/home/ylee/meme/fimo_out/", sequence_name)
csv_dir <- paste0(base_dir, "/alignment_csv")

fimo_base_path <- paste0(base_dir, "/")
dir.create(csv_dir)

motif_details <- alignment_details(rbp_list, All_RBP_motifs, fimo_base_path)

output_dir <- paste0(csv_dir, "/", basename(fimo_base_path), ".csv")
write.csv(motif_details, output_dir, row.names = FALSE)

# %% [markdown]
# ## Combine Motif Scanning Result - FERMT1/TPM2

# %%
sequence_name = "FERMT1"                                      ### Change Here : FERMT1, TPM2
base_dir <- paste0("/home/ylee/meme/fimo_out/", sequence_name)
csv_dir <- paste0(base_dir, "/alignment_csv")

fimo_base_paths <- paste0(list.dirs(base_dir, recursive = FALSE, full.names = TRUE), "/")
dir.create(csv_dir)

for (fimo_base_path in fimo_base_paths){
    motif_details <- alignment_details(rbp_list, All_RBP_motifs, fimo_base_path)    
    
    output_dir <- paste0(csv_dir, "/", basename(fimo_base_path), ".csv")
    print(output_dir)
    flush.console()
    write.csv(motif_details, output_dir, row.names = FALSE)   
}

# %%
if (sequence_name == "FERMT1"){
    mapped_data <- read.csv("/home/ylee/meme/FERMT1_TPM2_sequence/PANX1_NB_fragment_FERMT1_mapped_sequecnes_64_percent.csv", header = TRUE, fill = TRUE)
} else {     
    mapped_data <- read.csv("/home/ylee/meme/FERMT1_TPM2_sequence/PANX1_NB_fragment_TPM2_mapped_sequecnes_64_percent.csv", header = TRUE, fill = TRUE)
}

# %%
csv_paths <- list.files(csv_dir, recursive = FALSE, full.names = TRUE)
csv_paths <- csv_paths[grepl(paste0("^", sequence_name, "_\\d+\\.csv$"), basename(csv_paths))]

results <- alignment_combined_details(csv_paths, mapped_data, sequence_name)
write.csv(results$mapped_data, paste0(csv_dir, "/", sequence_name, "_mapped_motif_alignments_summary.csv"), row.names = FALSE) 
write.csv(results$alignment_combined, paste0(csv_dir, "/", sequence_name, "_mapped_motif_alignments.csv"), row.names = FALSE)

# %% [markdown]
# ## Combine Motif Scanning Result-Actg2

# %%
sequence_name = "Actg2_ctrl"                                ### Change Here : Actg2_hotspot, Actg2_ctrl, Actg2_random
base_dir <- paste0("/home/ylee/meme/fimo_out/", sequence_name)
csv_dir <- paste0(base_dir, "/alignment_csv")

fimo_base_paths <- paste0(list.dirs(base_dir, recursive = FALSE, full.names = TRUE), "/")
dir.create(csv_dir)

for (fimo_base_path in fimo_base_paths){
    motif_details <- alignment_details(rbp_list, All_RBP_motifs, fimo_base_path)    
    
    output_dir <- paste0(csv_dir, "/", basename(fimo_base_path), ".csv")
    write.csv(motif_details, output_dir, row.names = FALSE)   
}
# Out:
#    database RBP_name motif_id motif_alt_id
# 1 CisBP_RNA     FXR2     1.10      DGACRRR
#   motif_id motif_alt_id       sequence_name start stop strand  score p.value
# 1     1.10      DGACRRR Actg2_ctrl_1_P16368     6   12      + 10.897   8e-05
#   q.value matched_sequence
# 1 0.00304          GGACGAG
#   database RBP_name motif_id motif_alt_id
# 2 oRNAment     FXR2      1.2      DGACRRR
#   motif_id motif_alt_id       sequence_name start stop strand  score p.value
# 1      1.2      DGACRRR Actg2_ctrl_1_P16368     6   12      + 10.897   8e-05
#   q.value matched_sequence
# 1 0.00304          GGACGAG
#   database RBP_name motif_id motif_alt_id
# 1   mCross     ILF3    1.5.1  BKSAGCCTCNB
#   motif_id motif_alt_id       sequence_name start stop strand   score  p.value
# 1    1.5.1  BKSAGCCTCNB Actg2_ctrl_1_P16368     8   18      - 14.2879 4.53e-06
#    q.value matched_sequence
# 1 0.000136      CTGAGCCTCGT
#   database RBP_name motif_id motif_alt_id
# 3 oRNAment    MBNL1    1.1.2      GCWTGCN
#   motif_id motif_alt_id       sequence_name start stop strand   score  p.value
# 1    1.1.2      GCWTGCN Actg2_ctrl_1_P16368    19   25      - 11.0594 5.35e-05
#   q.value matched_sequence
# 1 0.00203          GCTTGCT
#   database RBP_name motif_id motif_alt_id
# 1   mCross     NPM1      1.7  DBCTCTGDGNB
#   motif_id motif_alt_id       sequence_name start stop strand   score p.value
# 1      1.7  DBCTCTGDGNB Actg2_ctrl_1_P16368    12   22      - 13.6768 1.1e-05
#    q.value matched_sequence
# 1 0.000329      TGCTCTGAGCC
#   database RBP_name motif_id motif_alt_id
# 7 oRNAment    PCBP2    1.4.2      NCCCCHN
#   motif_id motif_alt_id       sequence_name start stop strand   score p.value
# 1    1.4.2      NCCCCHN Actg2_ctrl_1_P16368     1    7      - 10.4898   8e-05
#   q.value matched_sequence
# 1 0.00304          CCCCCAC
#   database RBP_name motif_id motif_alt_id
# 6 oRNAment     RBM6      1.1      HGTCCCB
#   motif_id motif_alt_id       sequence_name start stop strand   score p.value
# 1      1.1      HGTCCCB Actg2_ctrl_1_P16368     4   10      - 10.6364   8e-05
#   q.value matched_sequence
# 1 0.00304          CGTCCCC
#   database RBP_name motif_id motif_alt_id
# 1   mCross    SF3A3      1.5  NBCTCTGVCNB
#   motif_id motif_alt_id       sequence_name start stop strand   score  p.value
# 1      1.5  NBCTCTGVCNB Actg2_ctrl_1_P16368    12   22      - 11.1579 8.07e-05
#   q.value matched_sequence
# 1 0.00242      TGCTCTGAGCC
#   database RBP_name motif_id motif_alt_id
# 2   mCross    SF3B4    1.2.1  NNCTCTGMCNB
#   motif_id motif_alt_id       sequence_name start stop strand   score  p.value
# 1    1.2.1  NNCTCTGMCNB Actg2_ctrl_1_P16368    12   22      - 11.5968 5.15e-05
#   q.value matched_sequence
# 1 0.00155      TGCTCTGAGCC
#   database RBP_name motif_id motif_alt_id
# 3   mCross     XPO5      1.7  NBTCTGACCHB
#   motif_id motif_alt_id       sequence_name start stop strand   score p.value
# 1      1.7  NBTCTGACCHB Actg2_ctrl_1_P16368    11   21      - 11.0986 6.7e-05
#   q.value matched_sequence
# 1 0.00201      GCTCTGAGCCT
#   database RBP_name motif_id motif_alt_id
# 8   mCross     XPO5      1.8  NNTGCTCTGNN
#   motif_id motif_alt_id       sequence_name start stop strand   score  p.value
# 1      1.8  NNTGCTCTGNN Actg2_ctrl_1_P16368    14   24      - 12.3306 2.67e-05
#   q.value matched_sequence
# 1   8e-04      CTTGCTCTGAG
#   database RBP_name motif_id motif_alt_id
# 1   mCross    XRCC6    1.3.1  BBTGCTSTGNN
#   motif_id motif_alt_id       sequence_name start stop strand   score p.value
# 1    1.3.1  BBTGCTSTGNN Actg2_ctrl_1_P16368    14   24      - 13.1579 1.5e-05
#    q.value matched_sequence
# 1 0.000451      CTTGCTCTGAG
#   database RBP_name motif_id motif_alt_id
# 5   mCross     FMR1      1.2  NNACCTGYGNB
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.2  NNACCTGYGNB Actg2_ctrl_2_P7825     3   13      + 11.0921 6.65e-05
#   q.value matched_sequence
# 1   0.002      CAACCTGGGTC
#   database RBP_name motif_id motif_alt_id
# 4   mCross     ILF3    1.7.1  NNCCCTGGTNB
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.7.1  NNCCCTGGTNB Actg2_ctrl_2_P7825     3   13      - 10.4366 8.99e-05
#   q.value matched_sequence
# 1  0.0027      GACCCAGGTTG
#    database RBP_name motif_id motif_alt_id
# 3 CisBP_RNA    RBM24        1      WGWGTGD
#   motif_id motif_alt_id      sequence_name start stop strand score  p.value
# 1        1      WGWGTGD Actg2_ctrl_2_P7825    16   22      +  11.2 6.51e-05
#   q.value matched_sequence
# 1 0.00247          AGTGTGA
#   database RBP_name motif_id motif_alt_id
# 4 oRNAment    RBM24      1.3      WGWGTGD
#   motif_id motif_alt_id      sequence_name start stop strand score  p.value
# 1      1.3      WGWGTGD Actg2_ctrl_2_P7825    16   22      +  11.2 6.51e-05
#   q.value matched_sequence
# 1 0.00247          AGTGTGA
#   database RBP_name motif_id motif_alt_id
# 1   mCross    SUGP2      1.9  BKKTCTCAGNN
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.9  BKKTCTCAGNN Actg2_ctrl_2_P7825     9   19      + 13.5493 8.98e-06
#   q.value matched_sequence
# 1 0.00027      GGGTCTCAGTG
#   database RBP_name motif_id motif_alt_id
# 2   mCross    DGCR8      1.1  BYCTAGCACYW
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.1  BYCTAGCACYW Actg2_ctrl_3_P4713     8   18      - 11.8384 3.96e-05
#   q.value matched_sequence
# 1 0.00127      GTCTAGCACCC
#   database RBP_name motif_id motif_alt_id
# 3   mCross     SBDS      1.3  BWCCGSGTTBC
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.3  BWCCGSGTTBC Actg2_ctrl_3_P4713     3   13      + 11.4404 7.23e-05
#   q.value matched_sequence
# 1 0.00231      CTCCAGGGTGC
#   database RBP_name motif_id motif_alt_id
# 7   mCross   SERBP1      1.6  SSTGCTTGASY
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.6  SSTGCTTGASY Actg2_ctrl_3_P4713     9   19      + 11.7429 2.45e-05
#    q.value matched_sequence
# 1 0.000783      GGTGCTAGACT
#   database RBP_name motif_id motif_alt_id
# 3   mCross    SF3B4      1.4  NNCTGACTCHB
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.4  NNCTGACTCHB Actg2_ctrl_3_P4713    16   26      + 10.6935 9.24e-05
#   q.value matched_sequence
# 1 0.00296      GACTGACCCCG
#    database RBP_name motif_id motif_alt_id
# 21   mCross    SRSF1    1.2.1  NNHBCTGGASV
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.2.1  NNHBCTGGASV Actg2_ctrl_3_P4713     2   12      - 11.7931 2.75e-05
#    q.value matched_sequence
# 1 0.000881      CACCCTGGAGC
#    database RBP_name motif_id motif_alt_id
# 23   mCross    SRSF1    1.4.2  NNMYCTGGANN
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.4.2  NNMYCTGGANN Actg2_ctrl_3_P4713     2   12      - 11.1129 7.87e-05
#   q.value matched_sequence
# 1 0.00252      CACCCTGGAGC
#   database RBP_name motif_id motif_alt_id
# 2   mCross    DGCR8      1.1  BYCTAGCACYW
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.1  BYCTAGCACYW Actg2_ctrl_4_P4710    10   20      - 11.8384 3.96e-05
#   q.value matched_sequence
# 1 0.00119      GTCTAGCACCC
#   database RBP_name motif_id motif_alt_id
# 3   mCross     SBDS      1.3  BWCCGSGTTBC
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.3  BWCCGSGTTBC Actg2_ctrl_4_P4710     5   15      + 11.4404 7.23e-05
#   q.value matched_sequence
# 1 0.00217      CTCCAGGGTGC
#   database RBP_name motif_id motif_alt_id
# 7   mCross     SBDS      1.1  HNGGCTMCAVN
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.1  HNGGCTMCAVN Actg2_ctrl_4_P4710     1   11      + 15.1101 1.23e-06
#    q.value matched_sequence
# 1 3.68e-05      CAGGCTCCAGG
#   database RBP_name motif_id motif_alt_id
# 7   mCross   SERBP1      1.6  SSTGCTTGASY
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1      1.6  SSTGCTTGASY Actg2_ctrl_4_P4710    11   21      + 11.7429 2.45e-05
#    q.value matched_sequence
# 1 0.000734      GGTGCTAGACT
#    database RBP_name motif_id motif_alt_id
# 21   mCross    SRSF1    1.2.1  NNHBCTGGASV
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.2.1  NNHBCTGGASV Actg2_ctrl_4_P4710     4   14      - 11.7931 2.75e-05
#    q.value matched_sequence
# 1 0.000826      CACCCTGGAGC
#    database RBP_name motif_id motif_alt_id
# 23   mCross    SRSF1    1.4.2  NNMYCTGGANN
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.4.2  NNMYCTGGANN Actg2_ctrl_4_P4710     4   14      - 11.1129 7.87e-05
#   q.value matched_sequence
# 1 0.00236      CACCCTGGAGC
#    database RBP_name motif_id motif_alt_id
# 17   mCross    DDX3X    1.2.2  NNCGGTRGCND
#   motif_id motif_alt_id      sequence_name start stop strand  score  p.value
# 1    1.2.2  NNCGGTRGCND Actg2_ctrl_5_P2922     2   12      - 11.439 5.47e-05
#   q.value matched_sequence
# 1 0.00186      CTCTGTAGCCG
#     database RBP_name motif_id motif_alt_id
# 18 CisBP_RNA    SNRPA    1.6.3      WGGAGAT
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.6.3      WGGAGAT Actg2_ctrl_5_P2922    14   20      - 11.5051 6.51e-05
#   q.value matched_sequence
# 1 0.00273          AGGAGAT
#    database RBP_name motif_id motif_alt_id
# 19 oRNAment    SNRPA    1.8.1      WGGAGAT
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.8.1      WGGAGAT Actg2_ctrl_5_P2922    14   20      - 11.5051 6.51e-05
#   q.value matched_sequence
# 1 0.00273          AGGAGAT
#    database RBP_name motif_id motif_alt_id
# 20    RBPDB    SNRPA    1.8.2      WGGAGAT
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.8.2      WGGAGAT Actg2_ctrl_5_P2922    14   20      - 11.4949 6.51e-05
#   q.value matched_sequence
# 1 0.00273          AGGAGAT
#    database RBP_name motif_id motif_alt_id
# 14   mCross    SRSF7     1.10  NNGAGATCTTY
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1     1.10  NNGAGATCTTY Actg2_ctrl_5_P2922    10   20      - 11.8684 3.54e-05
#   q.value matched_sequence
# 1  0.0012      AGGAGATCCTC
#    database RBP_name motif_id motif_alt_id
# 19   mCross    SRSF7    1.5.2  NVAGATCKTCN
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1    1.5.2  NVAGATCKTCN Actg2_ctrl_5_P2922     9   19      - 11.9868 4.14e-05
#   q.value matched_sequence
# 1 0.00141      GGAGATCCTCT
#    database RBP_name motif_id motif_alt_id
# 19   mCross    UCHL5     1.10  NVAGATCKTBN
#   motif_id motif_alt_id      sequence_name start stop strand   score  p.value
# 1     1.10  NVAGATCKTBN Actg2_ctrl_5_P2922     9   19      - 12.1408 3.21e-05
#   q.value matched_sequence
# 1 0.00109      GGAGATCCTCT

# %%
if (sequence_name == "Actg2_hotspot"){
    mapped_data <- read.csv("/home/ylee/meme/Actg2_sequence/Actg1_hotspot101_Actg2_mapped_sequecnes_68_percent.csv", header = TRUE, fill = TRUE)
} else if (sequence_name == "Actg2_ctrl"){
    mapped_data <- read.csv("/home/ylee/meme/Actg2_sequence/Actg1_ctrl_Actg2_mapped_sequecnes_68_percent.csv", header = TRUE, fill = TRUE)
} else {     
    mapped_data <- read.csv("/home/ylee/meme/Actg2_sequence/Actg1_random_Actg2_mapped_sequecnes_68_percent.csv", header = TRUE, fill = TRUE)
}

# %%
csv_paths <- list.files(csv_dir, recursive = FALSE, full.names = TRUE)
csv_paths <- csv_paths[grepl(paste0("^", sequence_name, "_\\d+\\.csv$"), basename(csv_paths))]

results <- alignment_combined_details(csv_paths, mapped_data, sequence_name)
write.csv(results$mapped_data, paste0(csv_dir, "/", sequence_name, "_mapped_motif_alignments_summary.csv"), row.names = FALSE) 
write.csv(results$alignment_combined, paste0(csv_dir, "/", sequence_name, "_mapped_motif_alignments.csv"), row.names = FALSE)
